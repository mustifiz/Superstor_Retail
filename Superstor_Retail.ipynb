# %% [markdown]
# ## Superstore_Retail

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Gibt eine boolesche Reihe zurück, die doppelte Zeilen bezeichnet.Summe
df.duplicated().sum()
# Out:
# 17

# %%
#Es gibt also 17 doppelte Einträge, die wir löschen sollten
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
# /var/folders/_q/9n3w18px7j550bc8mwyr1jk40000gn/T/ipykernel_9206/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# * From above Heatmap:
#
# * Sales and Profit are Moderately Correlated.
# * Discount and Profit are Negatively Correlated
# * Quantity and Profit are less Moderately Correlated.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Sales'],color='red',label='Sales',shade=True,bw=25)
sns.kdeplot(df['Profit'],color='Blue',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()

# %%
sns.pairplot(df,hue='Category')

# %%
sns.pairplot(df,hue='Segment')

# %%
sns.pairplot(df,hue='Region')

# %%
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
df["Segment"].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
df["Category"].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)


plt.tight_layout()

# %%
df["Sub-Category"].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,15))
plt.pie(df["Sub-Category"].value_counts(), labels= df["Sub-Category"].value_counts().index, autopct ="%2f")
plt.show()

# %%
st_profit=df.groupby(["State"])["Profit"].sum().nlargest(20)

# %%
st_profit
# Out:
# State
# California       76330.7891
# New York         74015.4622
# Washington       33368.2375
# Michigan         24428.0903
# Virginia         18597.9504
# Indiana          18382.9363
# Georgia          16250.0433
# Kentucky         11199.6966
# Minnesota        10823.1874
# Delaware          9977.3748
# New Jersey        9772.9138
# Wisconsin         8401.8004
# Rhode Island      7285.6293
# Maryland          7031.1788
# Massachusetts     6785.5016
# Missouri          6436.2105
# Alabama           5786.8253
# Oklahoma          4853.9560
# Arkansas          4008.6871
# Connecticut       3511.4918
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(15,8))
st_profit.plot.bar()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
sns.lineplot(data=df, x="Discount", y= "Profit")
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Quantity'])
plt.title('Quantity',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quantity')

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# ## Distribution of the data using the plot

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (10,10))
sns.distplot(df['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(df['Profit'], color = 'green',  ax = axs[0][1])
sns.distplot(df['Quantity'], color = 'orange',  ax = axs[1][0])
sns.distplot(df['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %%
data1= df.groupby("State")[["Sales","Profit"]].sum().sort_values(by="Sales", ascending=False)
data1[:].plot.bar(color = ["Green","Red"], figsize=(20,12))
plt.title("Profit-Loss and Sales across States")
plt.show()

# %% [markdown]
# * California and New York generate more profit compared to the other states.

# %% [markdown]
# ## Statewise Deal Analysis

# %%
df['Country'].value_counts()
# Out:
# United States    9977
# Name: Country, dtype: int64

# %%
df1 = df['State'].value_counts()
df1.head()
# Out:
# California      1996
# New York        1127
# Texas            983
# Pennsylvania     586
# Washington       502
# Name: State, dtype: int64

# %%
df1.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %%
df['State'].value_counts().mean()
# Out:
# 203.6122448979592

# %% [markdown]
# **Average number of deal per state is 204.**

# %% [markdown]
# ## City Wise analysis of the dealing

# %%
df2 = df['City'].value_counts()
df2=df2.head(50)

# %%
df2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('City')

plt.title('City Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# **Here is top 3 city where deals are Highest. 1. New York City 2. Los Angeles 3. Philadelphia.**

# %%
df['City'].value_counts().mean()
# Out:
# 18.789077212806028

# %% [markdown]
# **Average number of deal per city is 19.**

# %% [markdown]
# ## Segment wise analysis of Profit, Discount and sell

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
df_segment= df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.969279  0.158308  25.855188
# Corporate    234.185781  0.158159  30.499164
# Home Office  241.311234  0.147178  33.883643

# %%
#1. sales 2. Discount 3. Profit
df_segment.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(18, 20),
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = df_segment.index)
plt.title('Segment wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'Segment wise analysis of Sale, Discount, profit')

# %% [markdown]
# **Sales:**
#   - Consumer : 32%
#   - Corporate - 33.5%
#   - Home Office : 34.5%

# %% [markdown]
# **Discount :**
#   - Consumer : 15.8%
#   - Corporate : 15.8%
#   - Home Office : 14.7%

# %% [markdown]
# **Profit :**
#
#   - Consumer : 15.8%
#
#   - Corporate : 15.8%
#
#   - Home Office : 14.7%

# %% [markdown]
# **[1] Statewise Profit Analysis**

# %%
df['State'].value_counts().head(10)
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %%
df_state= df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            229.246629  0.072946   38.241878
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
df_state1=df_state.sort_values('Profit')

df_state1[['Profit']].plot(kind = 'bar', figsize = (15,4))
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# **_RESULT_**
#
# - **Vermont**: Highest Profit
#
# - **Ohio**: Lowest Profit

# %%
df_state['Sales'].plot(kind='pie',
                        figsize = (20,20),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('State wise analysis of Sale',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Sale')

# %% [markdown]
# - Highest amount of sales= **Wyoming(11.8%)**
# - Lowest amount of sales= **South Dakota(0.8%)**

# %% [markdown]
# **[3] Statewise Discount Analysis**

# %%
df_state1['Discount'].plot(kind='bar',figsize=(18,5))
plt.title('State wise analysis of Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# ## Citywise Analysis of the Profit

# %%
df_city= df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city = df_city.sort_values('Profit')
df_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
#1.Low Profit
df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'Pink')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %%
#2. High Profit
df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'Pink')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale, Discount, profit')

# %% [markdown]
# 30 CITIES WHICH HAS PROFIT IN POSITIVE
#
# 30 CITIES WHICH HAS PROFIT IN NEGATIVE
#
# THE BALANCE IS PRETTY GOOD HERE!

# %% [markdown]
# ## QUANTITY WISE SALES, PROFIT AND DISCOUNT ANALYSIS

# %%
df_quantity = df.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
df_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.377982  0.154844  16.027769
# 3         175.630896  0.153321  23.720306
# 4         272.779827  0.158373  37.227971
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
#1. sales 2. Discount 3. Profit
df_quantity.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(20, 20),
                     pctdistance=0.69,
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = df_quantity.index)
plt.title('Quantity wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'Quantity wise analysis of Sale, Discount, profit')

# %% [markdown]
# 13 Number of Quantity is high for sales and Profit.

# %% [markdown]
# ## CATAGORY WISE SALES DISCOUNT AND PROFIT

# %%
df_category = df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        350.002981  0.174027   8.697740
# Office Supplies  119.550107  0.157385  20.353403
# Technology       452.709276  0.132323  78.752002

# %%
df_category.plot.pie(subplots=True, 
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_category.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# - Maximun sales and Profit obtain in **Technology.**
# - Minimun profit obtain in **Furniture**

# %% [markdown]
# ## Sub-Category wise Sales, Profit and Discount

# %%
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.096896  0.074969    8.207059
# Binders        133.645972  0.372011   19.860710
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.971969  0.170244   43.198582
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.902745  0.138494   13.653476

# %% [markdown]
# **[1] BASED ON THE SALES**

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Sales'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Copier then Machine have High sales.

# %% [markdown]
# **[2] BASED ON THE DISCOUNT**

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Discount'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Binders , Machines and then tables have high Discount.**

# %% [markdown]
# **[3] BASED ON THE PROFIT**

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (10,5),
                                                              label=['Avg Sales Price($)','Profit($)'])
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# **COPIER : HIGHEST PROFIT AS WELL AS SELL**

# %% [markdown]
# ## REGION WISE ANALYSIS

# %%
df_region = df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.947759  0.240250  17.100421
# East     238.465798  0.145343  32.163905
# South    241.803645  0.147253  28.857673
# West     227.139254  0.109615  33.927281

# %%
df_region.plot.pie(subplots=True, 
                   figsize=(18, 20), 
                   autopct='%1.1f%%',
                   labels = df_region.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# **WEST : PROFIT IS HIGH**

# %% [markdown]
# ## SHIP MODE WISE ANALYSIS

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
df_shipmode = df.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
df_shipmode
# Out:
#                      Sales  Discount     Profit
# Ship Mode
# First Class     228.614490  0.164587  31.850134
# Same Day        236.755950  0.152675  29.283924
# Second Class    236.323750  0.138626  29.565956
# Standard Class  227.928858  0.160222  27.534715

# %%
df_shipmode.plot.pie(subplots=True,
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_shipmode.index)
# Out:
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# - Profit and Discount is high in First Class
# - Sales is high for Same day ship

# %% [markdown]
# ## RESULT AND CONCLUSION

# %% [markdown]
# - Gain surpasses that of transaction, but there exist some areas where profit could be enhanced.
# - First Class exhibits high levels of profit and discount.
# - Same day shipment experiences high sales.
# - Sub-category: Copier demonstrates significant profit and sales.
# - Sub-category: Binders, Machines, and subsequently tables are associated with substantial discounts.
# - Technology category achieves maximum sales and profit.
# - Furniture category attains minimum profit.
# - Vermont yields the highest profit among states.
# - Ohio records the lowest profit among states.
# - Home-office segment showcases high profit and sales.
# - Here are the top 3 cities with the highest number of deals:
#
#     1. New York City
#
#     2. Los Angeles
#
#     3. Philadelphia
#
#
#
# - Sales and profit exhibit a moderate correlation.
# - Quantity and profit demonstrate a relatively weaker correlation.
# - Discount and profit display a negative correlation.
# - Here are the top 3 states with the highest number of deals:
#
#     1. California
#
#     2. New York
#
#     3. Texas
#
# - **Wyoming** : Lowest number of deals; Wyoming also records the highest sales percentage at 11.8%.
# - Lowest sales amount: South Dakota with a sales percentage of 0.8%.

# %% [markdown]
# ## Model

# %% [markdown]
# ## Setting Features and Target Variables

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
X = df.drop(['Sales'] , axis = 1)
y= df.Sales

# %%
X.shape
# Out:
# (9977, 12)

# %%
X.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category  Quantity  Discount  \
# 0        42420  South        Furniture    Bookcases         2      0.00
# 1        42420  South        Furniture       Chairs         3      0.00
# 2        90036   West  Office Supplies       Labels         2      0.00
# 3        33311  South        Furniture       Tables         5      0.45
# 4        33311  South  Office Supplies      Storage         2      0.20
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
y.head()
# Out:
# 0    261.9600
# 1    731.9400
# 2     14.6200
# 3    957.5775
# 4     22.3680
# Name: Sales, dtype: float64
